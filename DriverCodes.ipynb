# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime, timedelta
import importlib

# %%
if 'google.colab' in str(get_ipython()):
    print('Running on CoLab')
    timenow = datetime.now()+timedelta(hours=-7)
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir("/content/drive/MyDrive/Chronical/2024_04/NaturalLanguageProcessing/TermCode")
else:
    print('Running on Local')
    timenow = datetime.now()

base_path = os.getcwd()
data_path = os.path.join(base_path, "data")
question_path = os.path.join(data_path, "questions")
code_path = os.path.join(data_path, "python")
generated_path = os.path.join(data_path, "generated")

timenow_str = f"{timenow.hour:02d}{timenow.minute:02d}{timenow.month:02d}{timenow.day:02d}"

print(f"{base_path=}")
print(f"{data_path=}")
print(f"{question_path=}")
print(f"{code_path=}")
print(f"{generated_path=}")
print(f"{timenow=}")
print(f"{timenow_str}")
# Out:
# Running on Local
# base_path='g:\\My Drive\\Chronical\\2024_04\\NaturalLanguageProcessing\\TermCode'
# data_path='g:\\My Drive\\Chronical\\2024_04\\NaturalLanguageProcessing\\TermCode\\data'
# question_path='g:\\My Drive\\Chronical\\2024_04\\NaturalLanguageProcessing\\TermCode\\data\\questions'
# code_path='g:\\My Drive\\Chronical\\2024_04\\NaturalLanguageProcessing\\TermCode\\data\\python'
# generated_path='g:\\My Drive\\Chronical\\2024_04\\NaturalLanguageProcessing\\TermCode\\data\\generated'
# timenow=datetime.datetime(2024, 5, 23, 14, 4, 54, 513007)
# 14040523

# %%
import ProblemSetReader
importlib.reload(ProblemSetReader)
problem_set_reader = ProblemSetReader.ProblemSetReader()
problem_set_df = problem_set_reader.get_dataframe()
problem_set_df
# Out:
#     idx                                           question        answer  \
# 0     1  If we list all the natural numbers below $10$ ...  2.331680e+05
# 1     2  Each new term in the Fibonacci sequence is gen...  4.613732e+06
# 2     3  The prime factors of $13195$ are $5, 7, 13$ an...  6.857000e+03
# 3     4  A palindromic number reads the same both ways....  9.066090e+05
# 4     5  $2520$ is the smallest number that can be divi...  2.327926e+08
# 5     6  The sum of the squares of the first ten natura...  2.516415e+07
# 6     7  By listing the first six prime numbers: $2, 3,...  1.047430e+05
# 7     9  A Pythagorean triplet is a set of three natura...  3.187500e+07
# 8    10  The sum of the primes below $10$ is $2 + 3 + 5...  1.429138e+11
# 9    15  Starting in the top left corner of a $2 \times...  1.378465e+11
# 10   16  $2^{15} = 32768$ and the sum of its digits is ...  1.366000e+03
# 11   19  \nYou are given the following information, but...  1.710000e+02
# 12   20  $n!$ means $n \times (n - 1) \times \cdots \ti...  6.480000e+02
# 13   24  A permutation is an ordered arrangement of obj...  2.783915e+09
# 14   28  Starting with the number $1$ and moving to the...  6.691710e+08
# 15   31  In the United Kingdom the currency is made up ...  7.368200e+04
# 16   34  $145$ is a curious number, as $1! + 4! + 5! = ...  4.073000e+04
# 17   35  The number, $197$, is called a circular prime ...  5.500000e+01
# 18   36  The decimal number, $585 = 1001001001_2$ (bina...  8.721870e+05
# 19   37  The number $3797$ has an interesting property....  7.483170e+05
# 20   39  If $p$ is the perimeter of a right angle trian...  8.400000e+02
# 21   41  We shall say that an $n$-digit number is pandi...  7.652413e+06
# 22   48  The series, $1^1 + 2^2 + 3^3 + \cdots + 10^{10...  9.110847e+09
# 23   50  The prime $41$, can be written as the sum of s...  9.976510e+05
# 24   52  It can be seen that the number, $125874$, and ...  1.428570e+05
# 25   56  A googol ($10^{100}$) is a massive number: one...  9.720000e+02
# 26   60  The primes $3$, $7$, $109$, and $673$, are qui...  2.603300e+04
# 27   62  The cube, $41063625$ ($345^3$), can be permute...  1.270360e+11
# 28   63  The $5$-digit number, $16807=7^5$, is also a f...  4.900000e+01
# 29   76  It is possible to write five as a sum in exact...  1.905693e+08
# 30   77  It is possible to write ten as the sum of prim...  7.100000e+01
# 31   79  A common security method used for online banki...  7.316289e+07
# 32   80  It is well known that if the square root of a ...  4.088600e+04
# 33   85  By counting carefully it can be seen that a re...  2.772000e+03
# 34   94  It is easily proved that no equilateral triang...  5.184083e+08
# 35  114  A row measuring seven units in length has red ...  1.647564e+10
# 36  117  Using a combination of grey square tiles and o...  1.008085e+14
# 37  118  Using all of the digits $1$ through $9$ and co...  4.468000e+04
# 38  119  The number $512$ is interesting because it is ...  2.481558e+14
# 39  132  A number consisting entirely of ones is called...  8.432960e+05
# 40  142  Find the smallest $x + y + z$ with integers $x...  1.006193e+06
# 41  146  The smallest positive integer $n$ for which th...  6.763333e+08
# 42  160  For any $N$, let $f(N)$ be the last five digit...  1.657600e+04
# 43  164  How many $20$ digit numbers $n$ (without any l...  3.781588e+14
# 44  172  How many $18$-digit numbers $n$ (without leadi...  2.274853e+17
# 45  173  We shall define a square lamina to be a square...  1.572729e+06
# 46  178  Consider the number $45656$. \nIt can be seen ...  1.264618e+11
# 47  179  Find the number of integers $1 \lt n \lt 10^7$...  9.862620e+05
# 48  187  A composite is a number containing at least tw...  1.742726e+07
# 49  206  Find the unique positive integer whose square ...  1.389019e+09
# 50  208  A robot moves in a series of one-fifth circula...  3.319514e+17
# 51  211  For a positive integer $n$, let $\sigma_2(n)$ ...  1.922365e+09
# 52  222  What is the length of the shortest pipe, of in...  1.590933e+06
# 53  231  The binomial coefficient $\displaystyle \binom...  7.526965e+12
# 54  249  Let $S = \{2, 3, 5, \dots, 4999\}$ be the set ...  9.275263e+15
# 55  250  Find the number of non-empty subsets of $\{1^1...  1.425481e+15
# 56  357  \nConsider the divisors of $30$: $1,2,3,5,6,10...  1.739024e+12
# 57  500  The number of divisors of $120$ is $16$.\nIn f...  3.540728e+07
#
#                                           python_code
# 0   \n\ndef compute():\n\tans = sum(x for x in ran...
# 1   \n\ndef compute():\n\tans = 0\n\tx = 1  # Repr...
# 2   \nimport math\n\n\ndef compute():\n\tn = 60085...
# 3   \n\ndef compute():\n\tans = max(i * j\n\t\tfor...
# 4   \nimport math\n\n\ndef compute():\n\tans = mat...
# 5   \n\ndef compute():\n\tN = 100\n\ts = sum(i for...
# 6   \nimport eulerlib, itertools\n\n\ndef compute(...
# 7   \n\ndef compute():\n\tPERIMETER = 1000\n\tfor ...
# 8   \nimport eulerlib\n\n\ndef compute():\n\tans =...
# 9   \nimport math\n\n\ndef compute():\n\treturn st...
# 10  \n\ndef compute():\n\tn = 2**1000\n\tans = sum...
# 11  \nimport datetime\n\n\ndef compute():\n\tans =...
# 12  \nimport math\n\n\ndef compute():\n\tn = math....
# 13  \nimport itertools\n\n\ndef compute():\n\tarr ...
# 14  \n\ndef compute():\n\tSIZE = 1001  # Must be o...
# 15  \n\ndef compute():\n\tTOTAL = 200\n\t\n\t# At ...
# 16  \nimport math\n\n\ndef compute():\n\t# As stat...
# 17  \nimport eulerlib\n\n\ndef compute():\n\tispri...
# 18  \n\ndef compute():\n\tans = sum(i for i in ran...
# 19  \nimport eulerlib, itertools\n\n\ndef compute(...
# 20  \n\ndef compute():\n\tans = max(range(1, 1001)...
# 21  \nimport eulerlib\n\n\ndef compute():\n\t# Not...
# 22  \n\ndef compute():\n\tMOD = 10**10\n\tans = su...
# 23  \nimport eulerlib\n\n\ndef compute():\n\tans =...
# 24  \nimport itertools\n\n\ndef compute():\n\tcond...
# 25  \n\ndef compute():\n\tans = max(sum(int(c) for...
# 26  \nimport eulerlib, functools, math\n\n\ndef co...
# 27  \nimport itertools\n\n\ndef compute():\n\tnumd...
# 28  \n\ndef compute():\n\tans = sum(1\n\t\tfor i i...
# 29  \n\ndef compute():\n\tLIMIT = 100\n\tpartition...
# 30  \nimport eulerlib, itertools\n\n\ndef compute(...
# 31  \nimport itertools\n\n\ndef compute():\n\t# On...
# 32  \nimport math\n\n\ndef compute():\n\tDIGITS = ...
# 33  \nimport math\n\n\ndef compute():\n\tTARGET = ...
# 34  \nimport math, itertools\n\n\ndef compute():\n...
# 35  \n\n\t\ndef compute():\n\t# Dynamic programmin...
# 36  \n\ndef compute():\n\t# Dynamic programming\n\...
# 37  \nimport eulerlib\n\n\ndef compute():\n\tispri...
# 38  \nimport itertools\n\n\ndef compute():\n\tINDE...
# 39  \nimport eulerlib, itertools\n\n\ndef compute(...
# 40  \nimport itertools, math\n\n\ndef compute():\n...
# 41  \nimport eulerlib, math\n\n\ndef compute():\n\...
# 42  \n\ndef compute():\n\tans = factorial_suffix(1...
# 43  \n\ndef compute():\n\tBASE = 10\n\tDIGITS = 20...
# 44  \nimport math\n\n\nLENGTH = 18    # >= 1\nMAX_...
# 45  \n\ndef compute():\n\tTILES = 10**6\n\tans = 0...
# 46  \nimport functools\n\n\ndef compute():\n\tLIMI...
# 47  \n\ndef compute():\n\tdivisors = [2] * (10**7 ...
# 48  \nimport eulerlib, math\n\n\ndef compute():\n\...
# 49  \n\ndef compute():\n\t# Initialize\n\tn = 1000...
# 50  \n\ndef compute():\n\tLIMIT = 70\n\t\n\t# Retu...
# 51  \nimport array, eulerlib, math\n\n\ndef comput...
# 52  \nimport eulerlib, math\n\n\ndef compute():\n\...
# 53  \nimport eulerlib\n\n\ndef compute():\n\tN = 2...
# 54  \nimport eulerlib\n\n\ndef compute():\n\tLIMIT...
# 55  \n\ndef compute():\n\t# Use dynamic programmin...
# 56  \nimport eulerlib, math\n\n\ndef compute():\n\...
# 57  \nimport eulerlib, heapq\n\n\ndef compute():\n...

# %% [markdown]
# # CodeGen Generation for Pass@k

# %%
import CodeGenAgent
importlib.reload(CodeGenAgent)
agent = CodeGenAgent.CodeGenAgent()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
df = problem_set_reader.get_dataframe()

# %%
agent.generate_pass_at_k_codes(df.loc[df['idx']>85], k=5, max_new_tokens=256)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   4%|▍         | 1/24 [00:24<09:23, 24.50s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   8%|▊         | 2/24 [00:46<08:29, 23.17s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  12%|█▎        | 3/24 [01:08<07:48, 22.32s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  17%|█▋        | 4/24 [01:29<07:15, 21.79s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  21%|██        | 5/24 [01:43<06:02, 19.09s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  25%|██▌       | 6/24 [02:04<05:56, 19.79s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  29%|██▉       | 7/24 [02:25<05:41, 20.10s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  33%|███▎      | 8/24 [02:46<05:27, 20.46s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  38%|███▊      | 9/24 [03:08<05:13, 20.89s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  42%|████▏     | 10/24 [03:28<04:49, 20.66s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  46%|████▌     | 11/24 [03:48<04:26, 20.49s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  50%|█████     | 12/24 [04:10<04:09, 20.80s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  54%|█████▍    | 13/24 [04:31<03:49, 20.90s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  58%|█████▊    | 14/24 [04:52<03:28, 20.88s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  62%|██████▎   | 15/24 [05:13<03:09, 21.11s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  67%|██████▋   | 16/24 [05:33<02:47, 20.88s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  71%|███████   | 17/24 [05:55<02:28, 21.18s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  75%|███████▌  | 18/24 [06:17<02:07, 21.17s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  79%|███████▉  | 19/24 [06:38<01:46, 21.20s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  83%|████████▎ | 20/24 [07:00<01:25, 21.46s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  88%|████████▊ | 21/24 [07:21<01:03, 21.25s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  92%|█████████▏| 22/24 [07:41<00:42, 21.05s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  96%|█████████▌| 23/24 [08:03<00:21, 21.19s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 100%|██████████| 24/24 [08:24<00:00, 21.00s/it]

# %%
len(df.loc[df['idx']>85])
# Out:
# 24

# %% [markdown]
# # Pass@K Evaluation

# %%
import HolisticEvaluator
importlib.reload(HolisticEvaluator)
evaluator = HolisticEvaluator.HolisticEvaluator()

# %%
pass_k_result_dict = evaluator.evaluate_pass_at_k(folder_path=generated_path, problem_set_df=problem_set_df, k=5, verbose=False)
# Out:
# Pass@K:  0.034482758620689655

# %%
pass_k_result_dict
# Out:
# {'pass_at_k_count': 2,
#  'total_count': 58,
#  'pass_at_k_ratio': 0.034482758620689655}

# %% [markdown]
# # Geval Evaluation

# %%
prompts_df = evaluator.create_prompts_better(prom_template_path=os.path.join(base_path, "Geval.txt"),
                                            answers_folder=generated_path, 
                                            df=problem_set_df)

# %%
print(prompts_df.shape)
prompts_df.head(10)
# Out:
# (58, 5)
#    question_id                                             prompt  \
# 0            1  You will be given one code answer for a math q...
# 1            2  You will be given one code answer for a math q...
# 2            3  You will be given one code answer for a math q...
# 3            4  You will be given one code answer for a math q...
# 4            5  You will be given one code answer for a math q...
# 5            6  You will be given one code answer for a math q...
# 6            7  You will be given one code answer for a math q...
# 7            9  You will be given one code answer for a math q...
# 8           10  You will be given one code answer for a math q...
# 9           15  You will be given one code answer for a math q...
#
#    correctness  efficiency  readability
# 0            0           0            0
# 1            0           0            0
# 2            0           0            0
# 3            0           0            0
# 4            0           0            0
# 5            0           0            0
# 6            0           0            0
# 7            0           0            0
# 8            0           0            0
# 9            0           0            0

# %%
print(prompts_df.iloc[0]['prompt'])
# Out:
# You will be given one code answer for a math question.
#
# Your task is to evaluate the quality of this answer from three perspectives:
#
# Please make sure you read and understand these instructions carefully. Please keep this document open while reviewing, and refer to it as needed.
#
# Evaluation Criteria:
#
# Correctness (1-5): Does the code correctly solve the problem as described?
# Efficiency (1-5): How efficient is the code in terms of time and space complexity?
# Readability (1-5): Is the code easy to read and understand? Consider aspects such as clarity, use of meaningful variable names, and code structure.
#
# After run the code the result is : wrong answer
#
# For the question:
#
# \n\nIf we list all the natural numbers below $10$ that are multiples of $3$ or $5$, we get $3, 5, 6$ and $9$. The sum of these multiples is $23$.
# Find the sum of all the multiples of $3$ or $5$ below $1000$.
# \n\n.
#
# Here is the code answer for this question:
#
# \n\n
#
#
# def find_three_of_five_multiples():
#     sum = 0
#     for i in range(10000):
#         if (i % 3) == 0 or (i % 5) == 0:
#             sum = sum + i
#     return sum
#
#
# """
# You have $n$ coins exactly for the same number, but you want to keep the smallest possible number of coins in the suitcase. How many different ways can you put the coins in suitcase?
# """
# .
#
# Evaluation Steps:
#
# Correctness: Check if the code produces the correct output for the given problem.
# Efficiency: Analyze the code's efficiency in terms of time and space complexity.
# Readability: Evaluate how easy the code is to read and understand.
# Provide a score for each criterion from 1 to 5, where 1 is the lowest and 5 is the highest. Please only output the content after output.
#
# Example:
# Correctness:
# Efficiency:
# Readability:

# %%
prompts_df.to_pickle(os.path.join(base_path, "prompts_df.pkl"))

# %%
prompts_df = pd.read_pickle(os.path.join(base_path, "prompts_df.pkl"))
prompts_df.head(5)
# Out:
#    question_id                                             prompt  \
# 0            1  You will be given one code answer for a math q...
# 1            2  You will be given one code answer for a math q...
# 2            3  You will be given one code answer for a math q...
# 3            4  You will be given one code answer for a math q...
# 4            5  You will be given one code answer for a math q...
#
#    correctness  efficiency  readability
# 0            2           2            4
# 1            1           1            2
# 2            1           1            2
# 3            1           2            3
# 4            1           1            2

# %%
import GPTAgent
importlib.reload(GPTAgent)
gpt_agent = GPTAgent.GPTAgent()

# %%
geval_result = evaluator.Geval(prompts_df, gpt_agent.generate_gpt, model="gpt-3.5-turbo")
# Out:
# New g4f version: 0.3.1.9 (current: 0.3.1.4) | pip install -U g4f
# Failed to parse output: Correctness: **5**
# The code correctly calculates the sum of the digits of the number $$2^{1000}$$ by continuously dividing the number by 10 and adding the remainder to a sum variable. The logic is sound, and it has been verified to produce the correct answer.
#
# Efficiency: **4**
# The code is quite efficient for this problem. It uses a simple while loop to iterate through each digit, which has a time complexity of O(n), where n is the number of digits in $$2^{1000}$$. However, since the number of digits is fixed and relatively small, the performance impact is minimal. There are no unnecessary computations or space allocations.
#
# Readability: **4**
# The code is straightforward and easy to understand. The variable names are meaningful, and the structure is clear. The use of comments could enhance understanding, and consistent indentation is maintained throughout, which aids readability. However, adding a comment explaining the overall approach or the purpose of the code block could further improve its readability.
#
# Failed to parse output: It seems there was an issue with the code provided as it resulted in a wrong answer. Without the actual code, I can't provide a detailed evaluation, but I can offer a general assessment based on common issues:
#
# **Correctness:** Since the code did not produce the correct answer, it would score a **1**. The algorithm or logic implemented may have flaws that need to be addressed to solve the problem correctly.
#
# **Efficiency:** Without seeing the code, I cannot accurately judge its efficiency. However, if the code produced a wrong answer, it's possible that it also has inefficiencies in its approach. Typically, an efficient solution for this type of problem would involve advanced algorithms like backtracking with optimizations to check for prime concatenations. I would tentatively score it a **2**, assuming there is at least some level of algorithmic implementation present.
#
# **Readability:** Again, without the code, I can't assess its readability. Readability involves clear naming conventions, proper structuring, and comments explaining the logic. If the code is incorrect, it often reflects poor readability as well, since it might indicate a lack of clear logic flow. Tentatively, I would score it a **2**, assuming the code is at least formatted and structured in a comprehensible way.
#
# If you can provide the code, I would be able to give a more accurate evaluation.
# Generation failed for prompt:  You will be given one code answer for a math question.
#
# Your task is to evaluate the quality of this answer from three perspectives:
#
# Please make sure you read and understand these instructions carefully. Please keep this document open while reviewing, and refer to it as needed.
#
# Evaluation Criteria:
#
# Correctness (1-5): Does the code correctly solve the problem as described?
# Efficiency (1-5): How efficient is the code in terms of time and space complexity?
# Readability (1-5): Is the code easy to read and understand? Consider aspects such as clarity, use of meaningful variable names, and code structure.
#
# After run the code the result is : timeout error
#
# For the question:
#
# \n\nConsider the number $45656$.
# It can be seen that each pair of consecutive digits of $45656$ has a difference of one.
# A number for which every pair of consecutive digits has a difference of one is called a step number.
# A pandigital number  contains every decimal digit from $0$ to $9$ at least once.
#
# How many pandigital step numbers less than $10^{40}$ are there?
#
# \n\n.
#
# Here is the code answer for this question:
#
# \n\n
#
# import math
# import os
# import random
# import re
# import sys
#
#
#
# if __name__ == '__main__':
#     n = 5000
#     sys.setrecursionlimit(
#         int(math.ceil((math.sqrt(1 + 8 * n) - 1) / 2)))
#
#     # Determine how many integers are less than or equal to 10^40
#     all_integers = range(10 ** 37 + 1)
#     p = 0
#     for i in all_integers:
#         if i < 10 ** 40:
#             is_pandigital = True
#             num = str(i)
#             for digit in num:
#                 if digit not in '3456789':
#                     is_pandigital = False
#                     break
#                 else:
#                     continue
#             if is_pandigital:
#                 p += 1
#     print(p + 2)
# .
#
# Evaluation Steps:
#
# Correctness: Check if the code produces the correct output for the given problem.
# Efficiency: Analyze the code's efficiency in terms of time and space complexity.
# Readability: Evaluate how easy the code is to read and understand.
# Provide a score for each criterion from 1 to 5, where 1 is the lowest and 5 is the highest. Please only output the content after output.
#
# Example:
# Correctness:
# Efficiency:
# Readability:

# %%
geval_result
# Out:
#     question_id                                             prompt  \
# 0             1  You will be given one code answer for a math q...
# 1             2  You will be given one code answer for a math q...
# 2             3  You will be given one code answer for a math q...
# 3             4  You will be given one code answer for a math q...
# 4             5  You will be given one code answer for a math q...
# 5             6  You will be given one code answer for a math q...
# 6             7  You will be given one code answer for a math q...
# 7             9  You will be given one code answer for a math q...
# 8            10  You will be given one code answer for a math q...
# 9            15  You will be given one code answer for a math q...
# 10           16  You will be given one code answer for a math q...
# 11           19  You will be given one code answer for a math q...
# 12           20  You will be given one code answer for a math q...
# 13           24  You will be given one code answer for a math q...
# 14           28  You will be given one code answer for a math q...
# 15           31  You will be given one code answer for a math q...
# 16           34  You will be given one code answer for a math q...
# 17           35  You will be given one code answer for a math q...
# 18           36  You will be given one code answer for a math q...
# 19           37  You will be given one code answer for a math q...
# 20           39  You will be given one code answer for a math q...
# 21           41  You will be given one code answer for a math q...
# 22           48  You will be given one code answer for a math q...
# 23           50  You will be given one code answer for a math q...
# 24           52  You will be given one code answer for a math q...
# 25           56  You will be given one code answer for a math q...
# 26           60  You will be given one code answer for a math q...
# 27           62  You will be given one code answer for a math q...
# 28           63  You will be given one code answer for a math q...
# 29           76  You will be given one code answer for a math q...
# 30           77  You will be given one code answer for a math q...
# 31           79  You will be given one code answer for a math q...
# 32           80  You will be given one code answer for a math q...
# 33           85  You will be given one code answer for a math q...
# 34           94  You will be given one code answer for a math q...
# 35          114  You will be given one code answer for a math q...
# 36          117  You will be given one code answer for a math q...
# 37          118  You will be given one code answer for a math q...
# 38          119  You will be given one code answer for a math q...
# 39          132  You will be given one code answer for a math q...
# 40          142  You will be given one code answer for a math q...
# 41          146  You will be given one code answer for a math q...
# 42          160  You will be given one code answer for a math q...
# 43          164  You will be given one code answer for a math q...
# 44          172  You will be given one code answer for a math q...
# 45          173  You will be given one code answer for a math q...
# 46          178  You will be given one code answer for a math q...
# 47          179  You will be given one code answer for a math q...
# 48          187  You will be given one code answer for a math q...
# 49          206  You will be given one code answer for a math q...
# 50          208  You will be given one code answer for a math q...
# 51          211  You will be given one code answer for a math q...
# 52          222  You will be given one code answer for a math q...
# 53          231  You will be given one code answer for a math q...
# 54          249  You will be given one code answer for a math q...
# 55          250  You will be given one code answer for a math q...
# 56          357  You will be given one code answer for a math q...
# 57          500  You will be given one code answer for a math q...
#
#     correctness  efficiency  readability
# 0             1           2            4
# 1             1           1            2
# 2             1           1            2
# 3             1           2            3
# 4             1           1            2
# 5             1           3            2
# 6             1           1            2
# 7             1           2            3
# 8             1           2            3
# 9             1           1            2
# 10            0           0            0
# 11            1           2            2
# 12            1           1            2
# 13            1           1            2
# 14            1           1            2
# 15            1           1            2
# 16            1           2            3
# 17            1           2            2
# 18            1           1            2
# 19            1           2            2
# 20            1           1            3
# 21            1           1            2
# 22            1           1            3
# 23            1           1            2
# 24            1           2            3
# 25            1           2            3
# 26            0           0            0
# 27            1           1            1
# 28            1           1            2
# 29            1           1            2
# 30            1           1            1
# 31            1           1            2
# 32            1           2            3
# 33            1           1            3
# 34            1           1            2
# 35            1           1            2
# 36            1           2            2
# 37            1           1            2
# 38            1           2            4
# 39            1           1            2
# 40            1           2            3
# 41            1           2            3
# 42            1           1            2
# 43            1           1            2
# 44            1           1            2
# 45            1           1            2
# 46            0           0            0
# 47            0           0            0
# 48            0           0            0
# 49            0           0            0
# 50            0           0            0
# 51            0           0            0
# 52            0           0            0
# 53            0           0            0
# 54            0           0            0
# 55            0           0            0
# 56            0           0            0
# 57            0           0            0

# %%
geval_result.to_pickle(os.path.join(base_path, "geval_result.pkl"))
