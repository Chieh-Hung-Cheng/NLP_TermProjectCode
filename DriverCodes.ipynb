# %%
import numpy as np
import pandas as pd
import os
from datetime import datetime, timedelta
import importlib

# %%
import code
from email.mime import base


if 'google.colab' in str(get_ipython()):
    print('Running on CoLab')
    timenow = datetime.now()+timedelta(hours=-7)
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir("/content/drive/MyDrive/Chronical/2024_04/NaturalLanguageProcessing/TermCode")
else:
    print('Running on Local')
    timenow = datetime.now()

base_path = os.getcwd()
data_path = os.path.join(base_path, "data")
question_path = os.path.join(data_path, "questions")
code_path = os.path.join(data_path, "python")
generated_path = os.path.join(data_path, "generated")

timenow_str = f"{timenow.hour:02d}{timenow.minute:02d}{timenow.month:02d}{timenow.day:02d}"

print(f"{base_path=}")
print(f"{data_path=}")
print(f"{question_path=}")
print(f"{code_path=}")
print(f"{generated_path=}")
print(f"{timenow=}")
print(f"{timenow_str}")
# Out:
# Running on CoLab
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# base_path='/content/drive/MyDrive/Chronical/2024_04/NaturalLanguageProcessing/TermCode'
# data_path='/content/drive/MyDrive/Chronical/2024_04/NaturalLanguageProcessing/TermCode/data'
# question_path='/content/drive/MyDrive/Chronical/2024_04/NaturalLanguageProcessing/TermCode/data/questions'
# code_path='/content/drive/MyDrive/Chronical/2024_04/NaturalLanguageProcessing/TermCode/data/python'
# generated_path='/content/drive/MyDrive/Chronical/2024_04/NaturalLanguageProcessing/TermCode/data/generated'
# timenow=datetime.datetime(2024, 5, 2, 16, 47, 46, 426212)
# 16470502

# %%
import ProblemSetReader
importlib.reload(ProblemSetReader)
problem_set_reader = ProblemSetReader.ProblemSetReader()
problem_set_reader.get_dataframe()
# Out:
#      idx                                           question           answer  \
# 0      1  If we list all the natural numbers below $10$ ...           233168
# 1      2  Each new term in the Fibonacci sequence is gen...          4613732
# 2      3  The prime factors of $13195$ are $5, 7, 13$ an...             6857
# 3      4  A palindromic number reads the same both ways....           906609
# 4      5  $2520$ is the smallest number that can be divi...        232792560
# ..   ...                                                ...              ...
# 197  493  $70$ coloured balls are placed in an urn, $10$...         6.818742
# 198  500  The number of divisors of $120$ is $16$.\nIn f...         35407281
# 199  518  Let $S(n) = \sum a + b + c$ over all triples $...  100315739184392
# 200  549  \nThe smallest number $m$ such that $10$ divid...  476001479068717
# 201  587  \nA square is drawn around a circle as shown i...             2240
#
# ...

# %%
import CodeGenAgent
importlib.reload(CodeGenAgent)
agent = CodeGenAgent.CodeGenAgent()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# # CodeGen Generation

# %%
available_indicies = problem_set_reader.get_available_indicies_list()
available_indicies = [i for i in available_indicies if i > 19]
agent.generate_code_for_indicies(available_indicies, batch_size=8)
# Out:
# ...
#  91%|█████████▏| 21/23 [05:54<00:37, 18.92s/it]Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
